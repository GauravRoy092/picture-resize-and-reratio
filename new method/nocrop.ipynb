# %%
from PIL import Image
import os
import io

# Input and output folders
input_folder = "gaurav"
output_folder = "result"
os.makedirs(output_folder, exist_ok=True)

# Desired final size and max size in KB
final_size = (600, 480)
max_file_size_kb = 200

for filename in os.listdir(input_folder):
    if filename.lower().endswith((".jpg", ".jpeg", ".png", ".bmp", ".webp")):
        img_path = os.path.join(input_folder, filename)

        try:
            img = Image.open(img_path).convert("RGB")
        except Exception as e:
            print(f"❌ Failed to open {filename}: {e}")
            continue

        # Resize image directly to 600x480 (no cropping)
        resized_img = img.resize(final_size, Image.Resampling.LANCZOS)

        # Compress image under 200KB
        output_path = os.path.join(output_folder, filename)
        quality = 85  # Start from good quality

        for q in range(quality, 10, -5):  # Try reducing quality in steps
            img_bytes = io.BytesIO()
            resized_img.save(img_bytes, format="JPEG", quality=q)
            size_kb = img_bytes.tell() / 1024

            if size_kb <= max_file_size_kb:
                with open(output_path, "wb") as f:
                    f.write(img_bytes.getvalue())
                print(f"✔️ Processed: {filename} ({size_kb:.1f} KB, quality={q})")
                break
        else:
            print(f"⚠️ Couldn't compress {filename} under {max_file_size_kb}KB")

print("✅ All images resized to 600x480 and saved in 'result' folder.")
# Out:
# ✔️ Processed: 10. GUNTUR CHILLI CHICKEN [A].JPG (49.1 KB, quality=85)
# ✔️ Processed: 11. LOOS PRAWNS.JPG (39.5 KB, quality=85)
# ✔️ Processed: 12. MUTTON MARAG.JPG (29.7 KB, quality=85)
# ✔️ Processed: 13. CHICKEN FRY PIECE PULAO [A].JPG (46.0 KB, quality=85)
# ✔️ Processed: 14. NIZAMI TARKARI BIRYANI, PAPAD CIGAR.JPG (46.7 KB, quality=85)
# ✔️ Processed: 15. APPOLO FISH.JPG (32.2 KB, quality=85)
# ✔️ Processed: 16. CHICKEN TIKKA LAAL MIRCH [A].JPG (45.2 KB, quality=85)
# ✔️ Processed: 17. KODAVA MUSHROOM.JPG (64.2 KB, quality=85)
# ✔️ Processed: 18. LAAL ROTI & CHICKEN BRUSCHETTA [A].JPG (50.5 KB, quality=85)
# ✔️ Processed: 19. KODI VEPUDU.JPG (58.0 KB, quality=85)
# ✔️ Processed: 2. PEANUT CHAAKHNA [A].JPG (27.3 KB, quality=85)
# ✔️ Processed: 20. KASAUNDI FISH TIKKA, TOUM MAYA [A].JPG (39.4 KB, quality=85)
# ✔️ Processed: 21. HYDERABADI CHICKEN DUM BIRYANI.JPG (39.3 KB, quality=85)
# ✔️ Processed: 22. CHICKEN TIKKA BIRYANI, CAPERS RAITA [A].JPG (29.2 KB, quality=85)
# ✔️ Processed: 23. GONGURA KODI PULAO.JPG (46.4 KB, quality=85)
# ✔️ Processed: 24. PAN TOSSED SUMMER VEGETABLES, ASIAN YELLOW CURRY.JPG (47.8 KB, quality=85)
# ✔️ Processed: 25. KERALA FRIED CALAMARI, COIN MALABARI PARATHA.JPG (49.6 KB, quality=85)
# ✔️ Processed: 26. PENNE ALFREDO, CHARCOAL MALAI CHICKEN.JPG (39.8 KB, quality=85)
# ✔️ Processed: 27. CHOCOLATE BROWNIE & NUTTY ICE CREAM.JPG (40.7 KB, quality=85)
# ✔️ Processed: 28. TENDER COCONUT MOUSSE, PALM JAGGERY [A].JPG (38.6 KB, quality=85)
# ✔️ Processed: 29. APRICOT DELIGHT.JPG (45.0 KB, quality=85)
# ✔️ Processed: 3. KOLHAPURI CHICKEN [A].JPG (32.4 KB, quality=85)
# ✔️ Processed: 30. KNAFEH CHENNA BALLS, FLAVOURED MILK [A].JPG (42.8 KB, quality=85)
# ✔️ Processed: 31. KARIMNAGAR FRIED CHICKEN WINGS, BBQ MAYO.JPG (50.5 KB, quality=85)
# ✔️ Processed: 32. CHICKEN DRUMSTICK.JPG (52.8 KB, quality=85)
# ✔️ Processed: 33.TANDOORI MURG.JPG (42.6 KB, quality=85)
# ✔️ Processed: 34. DONNE BIRYANI CARNATIC STYLE FRIED CHICKEN PAPPAD CRISP.JPG (46.3 KB, quality=85)
# ✔️ Processed: 35. VEG FRIED RICE.JPG (49.9 KB, quality=85)
# ✔️ Processed: 36. SICHUAN FRIED RICE.JPG (63.4 KB, quality=85)
# ✔️ Processed: 37. CHICKEN  FRIED RICE.JPG (51.1 KB, quality=85)
# ✔️ Processed: 38. NAAN,GARLIC NAAN,  BUTTER NAAN,.JPG (42.0 KB, quality=85)
# ✔️ Processed: 39. JEEDIPAPPU, KODI PAKODA.JPG (54.8 KB, quality=85)
# ✔️ Processed: 4.ROTI.JPG (29.8 KB, quality=85)
# ✔️ Processed: 40. FULLY LOADED CHICKEN NACHOS [A].JPG (48.8 KB, quality=85)
# ✔️ Processed: 40. FULLY LOADED CHICKEN NACHOS [B].JPG (54.3 KB, quality=85)
# ✔️ Processed: 41. CHICKEN 65.JPG (64.3 KB, quality=85)
# ✔️ Processed: 42. KODI PULUSU SOUP, CURRY LAVASH.JPG (55.6 KB, quality=85)
# ✔️ Processed: 43. WOK TOSSED SALT N PEPPER MUSHROOM.JPG (62.9 KB, quality=85)
# ✔️ Processed: 44. TANDOORI MALAI BROCCOLI, CHEESE CRUMB.JPG (55.2 KB, quality=85)
# ✔️ Processed: 45. VEG SECHUAN.JPG (58.0 KB, quality=85)
# ✔️ Processed: 46. ACHARI PANEER TIKKA.JPG (48.7 KB, quality=85)
# ✔️ Processed: 47. CHILLY PANEER.JPG (60.9 KB, quality=85)
# ✔️ Processed: 48. CHICKEN MAJESTIC.JPG (69.7 KB, quality=85)
# ✔️ Processed: 49. OCEAN CRUMBS ONION RINGS.JPG (48.8 KB, quality=85)
# ✔️ Processed: 5. FULLY LOADED VEG NACHOS.JPG (33.6 KB, quality=85)
# ✔️ Processed: 50. SWEET CORN.JPG (44.7 KB, quality=85)
# ✔️ Processed: 51. FRIES.JPG (54.5 KB, quality=85)
# ✔️ Processed: 52. KACHE GOSHT KI BIRYANI, CHESTNUT RAITA.JPG (50.2 KB, quality=85)
# ✔️ Processed: 53. HEALTHY SALAD JAR.JPG (24.7 KB, quality=85)
# ✔️ Processed: 54. CHICKEN LOLLYPOPS [A].JPG (63.7 KB, quality=85)
# ✔️ Processed: 54. CHICKEN LOLLYPOPS [B].JPG (63.8 KB, quality=85)
# ✔️ Processed: 55. MUTTON KEEMA PIZZA.JPG (71.5 KB, quality=85)
# ✔️ Processed: 56. KOTHIMEERA PANEER PULAO.JPG (45.9 KB, quality=85)
# ✔️ Processed: 57. MAC AND CHEESE PAKORA BITES [A].JPG (52.8 KB, quality=85)
# ✔️ Processed: 57. MAC AND CHEESE PAKORA BITES [B].JPG (56.9 KB, quality=85)
# ✔️ Processed: 58. WOK TOSSED BASIL CHILLY CHICKEN.JPG (66.4 KB, quality=85)
# ✔️ Processed: 59. GONGURA MUTTON PULAO.JPG (56.1 KB, quality=85)
# ✔️ Processed: 6. MUTTON MASALA LUHKMI, SWEET GINGER & MINT CHUTNEY.JPG (48.6 KB, quality=85)
# ✔️ Processed: 60. MURG MALAI TIKKA.JPG (53.4 KB, quality=85)
# ✔️ Processed: 61. SABJI MILONI HANDI.JPG (59.5 KB, quality=85)
# ✔️ Processed: 62. PANEER LABABDAR.JPG (62.2 KB, quality=85)
# ✔️ Processed: 63. KODIGUDDU VEPUDU.JPG (64.5 KB, quality=85)
# ✔️ Processed: 64. CHILLY BABY CORN.JPG (52.5 KB, quality=85)
# ✔️ Processed: 65. VELLULLI ROYYALA VEPUDU.JPG (54.8 KB, quality=85)
# ✔️ Processed: 66. ASLAM BUTTER CHICKEN, ALMOND SLIVER.JPG (45.3 KB, quality=85)
# ✔️ Processed: 67. ANDHRA CHEPA FRY.JPG (51.5 KB, quality=85)
# ✔️ Processed: 68. LOTUS ROOT KOFTA, KASHMIRI ROGAN JOSH LACCHA PARATHA.JPG (53.0 KB, quality=85)
# ✔️ Processed: 69. BAGHARA RICE.JPG (54.4 KB, quality=85)
# ✔️ Processed: 7. CREAM OF TOMOTO SOUP.JPG (37.1 KB, quality=85)
# ✔️ Processed: 70. FARMERS VEG PIZZA.JPG (63.8 KB, quality=85)
# ✔️ Processed: 71. ANDHRA FISH FRY.JPG (53.0 KB, quality=85)
# ✔️ Processed: 72. AMRITSARI FISH N CHIPS DESI GHEE HOLLANDAISE.JPG (47.7 KB, quality=85)
# ✔️ Processed: 73. VEG CORN PALAK.JPG (53.7 KB, quality=85)
# ✔️ Processed: 74. GOAN FISH CURRY, COCONUT RICE.JPG (52.2 KB, quality=85)
# ✔️ Processed: 75. CHICKEN TIKKA PIZZA.JPG (65.7 KB, quality=85)
# ✔️ Processed: 76. HAND PULLED BUTTER CHICKEN, BUTTER NAAN [A].JPG (60.2 KB, quality=85)
# ✔️ Processed: 76. HAND PULLED BUTTER CHICKEN, BUTTER NAAN [B].JPG (54.3 KB, quality=85)
# ✔️ Processed: 77. CHAMP TAJDAR, ACHARI MAYO.JPG (41.4 KB, quality=85)
# ✔️ Processed: 8. TANDOORI MARGARITA KULCHAS.JPG (43.0 KB, quality=85)
# ✔️ Processed: 9. BEER BATTER FRIED CHICKEN, BURANI CREAM.JPG (32.1 KB, quality=85)
# ✔️ Processed: CHICKEN FRY PIECE PULAO [B].JPG (54.7 KB, quality=85)
# ✔️ Processed: CHICKEN TIKKA BIRYANI, CAPERS RAITA [B].JPG (47.7 KB, quality=85)
# ✔️ Processed: CHICKEN TIKKA LAAL MIRCH [B].JPG (52.3 KB, quality=85)
# ✔️ Processed: CHOCOLATE BROWNIE & NUTTY ICE CREAM.JPG (57.3 KB, quality=85)
# ✔️ Processed: GUNTUR CHILLI CHICKEN [B].JPG (51.4 KB, quality=85)
# ✔️ Processed: KASAUNDI FISH TIKKA, TOUM MAYA [B].JPG (45.7 KB, quality=85)
# ✔️ Processed: KNAFEH CHENNA BALLS FLAVOURED MILK [B].JPG (45.1 KB, quality=85)
# ✔️ Processed: KOLHAPURI CHICKEN [B].JPG (46.8 KB, quality=85)
# ✔️ Processed: LAAL ROTI & CHICKEN BRUSCHETTA [B].JPG (44.9 KB, quality=85)
# ✔️ Processed: PEANUT CHAAKHNA [B].JPG (39.2 KB, quality=85)
# ✔️ Processed: TENDER COCONUT MOUSSE, PALM JAGGERY [B].JPG (37.8 KB, quality=85)
# ✅ All images resized to 600x480 and saved in 'result' folder.
